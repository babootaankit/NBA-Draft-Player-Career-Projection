# %%
import pandas as pd

# %%
data_source = "Resources/draft_data.csv"
draft_data = pd.read_csv(data_source)
draft_data
# Out:
#      Unnamed: 0               Player  Pick Position                   ID  \
# 0             0          Tim Pickett    44       SG          tim-pickett
# 1             1           Chris Paul     4       PG           chris-paul
# 2             2         Brandon Bass    33       PF         brandon-bass
# 3             3         Emeka Okafor     2       PF         emeka-okafor
# 4             4       Raymond Felton     5       PG       raymond-felton
# ..          ...                  ...   ...      ...                  ...
# 618         618       Doug McDermott    11       SF       doug-mcdermott
# 619         619     Roy Devyn Marble    56       SF     roy-devyn-marble
# 620         620  Willie Cauley-Stein     6        C  willie-cauley-stein
# 621         621         Jarvis Hayes    10       SG         jarvis-hayes
# 622         622          Steve Blake    38       PG          steve-blake
#
#      Draft Year  Projected SPM  Superstar   Starter  Role Player      Bust
# ...

# %%
html_table = draft_data.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>Player</th>\n      <th>Pick</th>\n      <th>Position</th>\n      <th>ID</th>\n      <th>Draft Year</th>\n      <th>Projected SPM</th>\n      <th>Superstar</th>\n      <th>Starter</th>\n      <th>Role Player</th>\n      <th>Bust</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>Tim Pickett</td>\n      <td>44</td>\n      <td>SG</td>\n      <td>tim-pickett</td>\n      <td>2004</td>\n      <td>-1.309528</td>\n      <td>0.000869</td>\n      <td>0.038589</td>\n      <td>0.308919</td>\n      <td>0.651623</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Chris Paul</td>\n      <td>4</td>\n      <td>PG</td>\n      <td>chris-paul</td>\n      <td>2005</td>\n      <td>1.516427</td>\n      <td>0.163319</td>\n      <td>0.489972</td>\n      <td>0.099133</td>\n      <td>0.247577</td>\n    </tr
# ...

# %%
draft_data.to_html('dataset.html')
